# %% [markdown]
# <a href="https://colab.research.google.com/github/rajuguruswamy/python-repo/blob/main/Objects.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## class and object
class person():
  print("hai")
  a=10
obj=person()
print(obj)
print(obj.a)
print(type(obj))
# Out:
# hai
# ...
# 10
# <class '__main__.person'>

# %%
class person():
  print("hai")
  a=10
obj=person()
obj2=person()
print(obj.a)
print(obj2.a)
# Out:
# hai
# 10
# 10

# %%
## Functions
